# %% [markdown]
# <a href="https://colab.research.google.com/github/022000FERNANDO/upsrj-machine-learning/blob/main/Breastcancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets        import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree            import DecisionTreeClassifier, plot_tree
from sklearn.metrics         import accuracy_score, classification_report, confusion_matrix

# %%
#CARGA BASE DE DATOS
data = load_breast_cancer()
print(data.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
#VARIABLES PARA NUESTRO MODELO
x = data.data
y = data.target
feature_names = data.feature_names
target_names = data.target_names

# %%
#DIVISION DE DATOS
x_train, x_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.3,
    random_state=42,
    stratify=y
    )

# %%
# Creación y entrenamiento del modelo
model = DecisionTreeClassifier(
    criterion="gini",
    max_depth=4,
    random_state=42
)

model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
#prediccion
y_pred = model.predict(x_test)

# %%
#evaluacion

print(f"accuracy score: {accuracy_score(y_test, y_pred)}")
print(f"confussion matrix: {confusion_matrix(y_test, y_pred)}")
print(f"classification report: {classification_report(y_test, y_pred)}")
# Out:
# accuracy score: 0.9239766081871345
# confussion matrix: [[ 57   7]
#  [  6 101]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90        64
#            1       0.94      0.94      0.94       107
#
#     accuracy                           0.92       171
#    macro avg       0.92      0.92      0.92       171
# weighted avg       0.92      0.92      0.92       171

# %%
plt.figure(figsize=(24,16))
plot_tree(
    model,
    feature_names=feature_names,
    class_names=target_names,
    filled=True,
    )
plt.title("Breast cancer prediction")
plt.show()
